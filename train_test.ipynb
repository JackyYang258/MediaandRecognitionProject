# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from tqdm import tqdm
import numpy as np
from baseline import Net

torch.manual_seed(42)

# 加载和预处理CIFAR-10数据集
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(), # FLips the image w.r.t horizontal axis
    transforms.RandomRotation(10),     #Rotates the image to a specified angel
    transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)), #Performs actions like zooms, change shear angles.
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2), # Set the color params
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
# 加载修改后的标签
modified_labels = np.load('./modified_labels.npy')
train_dataset.targets = modified_labels.tolist()

# 创建DataLoader
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

def to_device(data, device):
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:16<00:00, 10568093.57it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Using device: cuda

# %%
import matplotlib.pyplot as plt
# 设置训练环节
model = Net().to(device) 
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# 训练模型
num_epochs = 30
train_losses = []
train_accuracies = []
for epoch in range(num_epochs):
    epoch_losses = []  
    batchidx = 0
    with tqdm(train_loader, unit="batch") as tepoch:
        for images, labels in tepoch:
            images, labels = to_device(images, device), to_device(labels, device)
            tepoch.set_description(f"Epoch {epoch + 1}")
            optimizer.zero_grad()
            outputs = model(images)
            if batchidx > 390 and epoch > 10:
                believe = outputs[torch.arange(outputs.size(0)), labels]
                indices = torch.nonzero(believe > 1).view(-1)
                #delete the data with idx in indices
                outputs = torch.index_select(outputs, 0, indices)
                labels = torch.index_select(labels, 0, indices)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_losses.append(loss.item())
            tepoch.set_postfix(loss=loss.item())
            batchidx += 1
    epoch_loss_avg = sum(epoch_losses) / len(epoch_losses)
    train_losses.append(epoch_loss_avg)
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in test_loader:
            images, labels = to_device(images, device), to_device(labels, device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        train_accuracies.append(accuracy)
        print(f'Epoch {epoch + 1}, Accuracy on the test set: {accuracy:.2f}%')

    # Switch back to training mode
    model.train()

plt.plot(train_losses, label='Training Loss', color='blue')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss and Test Accuracy Curves')
plt.legend(loc='upper left')

# 创建第二个 y 轴
plt.twinx()

# 绘制测试准确率曲线
plt.plot(train_accuracies, label='Test Accuracy', color='red')
plt.ylabel('Accuracy')

plt.show()

# 评估模型
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images, labels = to_device(images, device), to_device(labels, device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print(f'Accuracy of the network on the 10000 test images: {100 * correct / total:.2f}%')
# Out:
# Epoch 1: 100%|██████████| 782/782 [00:15<00:00, 51.69batch/s, loss=2.01]
# Epoch 1, Accuracy on the test set: 51.30%
# Epoch 2: 100%|██████████| 782/782 [00:14<00:00, 54.10batch/s, loss=1.95]
# Epoch 2, Accuracy on the test set: 57.96%
# Epoch 3: 100%|██████████| 782/782 [00:14<00:00, 53.71batch/s, loss=1.42]
# Epoch 3, Accuracy on the test set: 60.39%
# Epoch 4: 100%|██████████| 782/782 [00:14<00:00, 55.05batch/s, loss=1.32]
# Epoch 4, Accuracy on the test set: 63.00%
# Epoch 5: 100%|██████████| 782/782 [00:14<00:00, 55.02batch/s, loss=1.73]
# Epoch 5, Accuracy on the test set: 64.85%
# Epoch 6: 100%|██████████| 782/782 [00:14<00:00, 54.02batch/s, loss=1.69]
# Epoch 6, Accuracy on the test set: 67.45%
# Epoch 7: 100%|██████████| 782/782 [00:14<00:00, 54.38batch/s, loss=1.86]
# Epoch 7, Accuracy on the test set: 67.20%
# Epoch 8: 100%|██████████| 782/782 [00:14<00:00, 54.64batch/s, loss=1.77]
# Epoch 8, Accuracy on the test set: 68.55%
# Epoch 9: 100%|██████████| 782/782 [00:14<00:00, 54.39batch/s, loss=1.53]
# Epoch 9, Accuracy on the test set: 70.03%
# Epoch 10: 100%|██████████| 782/782 [00:14<00:00, 54.58batch/s, loss=1.7]
# Epoch 10, Accuracy on the test set: 69.51%
# Epoch 11: 100%|██████████| 782/782 [00:14<00:00, 54.55batch/s, loss=1.02]
# Epoch 11, Accuracy on the test set: 69.89%
# Epoch 12: 100%|██████████| 782/782 [00:14<00:00, 53.07batch/s, loss=0.353]
# Epoch 12, Accuracy on the test set: 68.92%
# Epoch 13: 100%|██████████| 782/782 [00:14<00:00, 53.64batch/s, loss=0.542]
# Epoch 13, Accuracy on the test set: 68.63%
# Epoch 14: 100%|██████████| 782/782 [00:14<00:00, 53.96batch/s, loss=0.641]
# Epoch 14, Accuracy on the test set: 70.10%
# Epoch 15: 100%|██████████| 782/782 [00:14<00:00, 54.03batch/s, loss=0.779]
# Epoch 15, Accuracy on the test set: 69.38%
# Epoch 16: 100%|██████████| 782/782 [00:14<00:00, 54.22batch/s, loss=0.344]
# Epoch 16, Accuracy on the test set: 70.96%
# Epoch 17: 100%|██████████| 782/782 [00:14<00:00, 54.07batch/s, loss=0.61]
# Epoch 17, Accuracy on the test set: 70.55%
# Epoch 18: 100%|██████████| 782/782 [00:14<00:00, 54.17batch/s, loss=0.46]
# Epoch 18, Accuracy on the test set: 70.83%
# Epoch 19: 100%|██████████| 782/782 [00:14<00:00, 53.62batch/s, loss=0.559]
# Epoch 19, Accuracy on the test set: 70.99%
# Epoch 20: 100%|██████████| 782/782 [00:14<00:00, 53.68batch/s, loss=0.858]
# Epoch 20, Accuracy on the test set: 71.96%
# Epoch 21: 100%|██████████| 782/782 [00:14<00:00, 53.53batch/s, loss=0.707]
# Epoch 21, Accuracy on the test set: 72.33%
# Epoch 22: 100%|██████████| 782/782 [00:14<00:00, 53.62batch/s, loss=0.586]
# Epoch 22, Accuracy on the test set: 71.41%
# Epoch 23: 100%|██████████| 782/782 [00:14<00:00, 53.57batch/s, loss=0.502]
# Epoch 23, Accuracy on the test set: 72.64%
# Epoch 24: 100%|██████████| 782/782 [00:14<00:00, 53.96batch/s, loss=0.715]
# Epoch 24, Accuracy on the test set: 72.28%
# Epoch 25: 100%|██████████| 782/782 [00:14<00:00, 53.87batch/s, loss=0.685]
# Epoch 25, Accuracy on the test set: 73.45%
# Epoch 26: 100%|██████████| 782/782 [00:14<00:00, 53.62batch/s, loss=0.617]
# Epoch 26, Accuracy on the test set: 72.48%
# Epoch 27: 100%|██████████| 782/782 [00:14<00:00, 53.51batch/s, loss=0.484]
# Epoch 27, Accuracy on the test set: 73.40%
# Epoch 28: 100%|██████████| 782/782 [00:14<00:00, 53.68batch/s, loss=0.43]
# Epoch 28, Accuracy on the test set: 72.32%
# Epoch 29: 100%|██████████| 782/782 [00:13<00:00, 56.26batch/s, loss=0.853]
# Epoch 29, Accuracy on the test set: 72.85%
# Epoch 30: 100%|██████████| 782/782 [00:13<00:00, 57.40batch/s, loss=0.49]
# Epoch 30, Accuracy on the test set: 74.10%
# Epoch 31: 100%|██████████| 782/782 [00:13<00:00, 57.32batch/s, loss=0.193]
# Epoch 31, Accuracy on the test set: 73.47%
# Epoch 32: 100%|██████████| 782/782 [00:13<00:00, 58.07batch/s, loss=0.38]
# Epoch 32, Accuracy on the test set: 72.39%
# Epoch 33: 100%|██████████| 782/782 [00:13<00:00, 57.24batch/s, loss=0.333]
# Epoch 33, Accuracy on the test set: 73.94%
# Epoch 34: 100%|██████████| 782/782 [00:13<00:00, 57.58batch/s, loss=0.443]
# Epoch 34, Accuracy on the test set: 74.26%
# Epoch 35: 100%|██████████| 782/782 [00:13<00:00, 57.33batch/s, loss=0.62]
# Epoch 35, Accuracy on the test set: 72.91%
# Epoch 36: 100%|██████████| 782/782 [00:13<00:00, 56.98batch/s, loss=0.27]
# Epoch 36, Accuracy on the test set: 74.28%
# Epoch 37: 100%|██████████| 782/782 [00:14<00:00, 55.39batch/s, loss=0.279]
# Epoch 37, Accuracy on the test set: 74.00%
# Epoch 38: 100%|██████████| 782/782 [00:13<00:00, 56.37batch/s, loss=0.312]
# Epoch 38, Accuracy on the test set: 74.38%
# Epoch 39: 100%|██████████| 782/782 [00:14<00:00, 55.42batch/s, loss=0.81]
# Epoch 39, Accuracy on the test set: 74.51%
# Epoch 40: 100%|██████████| 782/782 [00:14<00:00, 53.84batch/s, loss=0.677]
# Epoch 40, Accuracy on the test set: 74.09%
# Epoch 41: 100%|██████████| 782/782 [00:14<00:00, 55.65batch/s, loss=0.538]
# Epoch 41, Accuracy on the test set: 75.32%
# Epoch 42: 100%|██████████| 782/782 [00:13<00:00, 57.27batch/s, loss=0.391]
# Epoch 42, Accuracy on the test set: 74.46%
# Epoch 43: 100%|██████████| 782/782 [00:13<00:00, 56.35batch/s, loss=0.499]
# Epoch 43, Accuracy on the test set: 74.95%
# Epoch 44: 100%|██████████| 782/782 [00:14<00:00, 55.40batch/s, loss=0.234]
# Epoch 44, Accuracy on the test set: 75.89%
# Epoch 45: 100%|██████████| 782/782 [00:14<00:00, 53.69batch/s, loss=0.45]
# Epoch 45, Accuracy on the test set: 75.42%
# Epoch 46: 100%|██████████| 782/782 [00:13<00:00, 57.05batch/s, loss=0.885]
# Epoch 46, Accuracy on the test set: 75.86%
# Epoch 47: 100%|██████████| 782/782 [00:13<00:00, 57.17batch/s, loss=0.593]
# Epoch 47, Accuracy on the test set: 75.95%
# Epoch 48: 100%|██████████| 782/782 [00:13<00:00, 56.86batch/s, loss=0.788]
# Epoch 48, Accuracy on the test set: 75.47%
# Epoch 49: 100%|██████████| 782/782 [00:13<00:00, 57.35batch/s, loss=0.382]
# Epoch 49, Accuracy on the test set: 75.08%
# Epoch 50: 100%|██████████| 782/782 [00:13<00:00, 57.36batch/s, loss=0.353]
# Epoch 50, Accuracy on the test set: 75.23%
# Accuracy of the network on the 10000 test images: 75.23%

# %%
import matplotlib.pyplot as plt
import numpy as np

# CIFAR-10类别标签
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# 选择要显示的图片数量
num_images = 32
# 创建图形和子图
fig, axs = plt.subplots(4, 8, figsize=(10, 5))
axs = axs.ravel()

for i in range(num_images):
    idx = torch.randint(len(test_dataset), size=(1,)).item()
    image, label = test_dataset[idx]
    # 使用训练好的模型进行预测
    model.eval()
    with torch.no_grad():
        image = image.unsqueeze(0)
        image = image.to(device)
        output = model(image)
        _, predicted = torch.max(output.data, 1)
        predicted_label = predicted.item()
    # 反归一化
    image = image / 2 + 0.5  # unnormalize
    npimg = image.cpu().numpy()[0]
    # 显示图片，并根据预测结果设置标签颜色
    axs[i].imshow(np.transpose(npimg, (1, 2, 0)))
    axs[i].set_title(classes[predicted_label], color='red' if label != predicted_label else 'green')
    axs[i].axis('off')
plt.tight_layout()
plt.show()
